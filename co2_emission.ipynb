# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pickle

# %%
data=pd.read_csv('CO2 Emissions_Canada.csv')
data.head()
# Out:
#     Make       Model Vehicle Class  Engine Size(L)  Cylinders Transmission  \
# 0  ACURA         ILX       COMPACT             2.0          4          AS5
# 1  ACURA         ILX       COMPACT             2.4          4           M6
# 2  ACURA  ILX HYBRID       COMPACT             1.5          4          AV7
# 3  ACURA     MDX 4WD   SUV - SMALL             3.5          6          AS6
# 4  ACURA     RDX AWD   SUV - SMALL             3.5          6          AS6
#
#   Fuel Type  Fuel Consumption City (L/100 km)  \
# 0         Z                               9.9
# 1         Z                              11.2
# 2         Z                               6.0
# 3         Z                              12.7
# 4         Z                              12.1
#
#    Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 0                              6.7                               8.5
# 1                              7.7                               9.6
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7385 entries, 0 to 7384
# Data columns (total 12 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Make                              7385 non-null   object
#  1   Model                             7385 non-null   object
#  2   Vehicle Class                     7385 non-null   object
#  3   Engine Size(L)                    7385 non-null   float64
#  4   Cylinders                         7385 non-null   int64
#  5   Transmission                      7385 non-null   object
#  6   Fuel Type                         7385 non-null   object
#  7   Fuel Consumption City (L/100 km)  7385 non-null   float64
#  8   Fuel Consumption Hwy (L/100 km)   7385 non-null   float64
#  9   Fuel Consumption Comb (L/100 km)  7385 non-null   float64
#  10  Fuel Consumption Comb (mpg)       7385 non-null   int64
# ...

# %%
data.describe()
# Out:
#        Engine Size(L)    Cylinders  Fuel Consumption City (L/100 km)  \
# count     7385.000000  7385.000000                       7385.000000
# mean         3.160068     5.615030                         12.556534
# std          1.354170     1.828307                          3.500274
# min          0.900000     3.000000                          4.200000
# 25%          2.000000     4.000000                         10.100000
# 50%          3.000000     6.000000                         12.100000
# 75%          3.700000     6.000000                         14.600000
# max          8.400000    16.000000                         30.600000
#
#        Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# count                      7385.000000                       7385.000000
# mean                          9.041706                         10.975071
# std                           2.224456                          2.892506
# ...

# %%
data.dtypes
# Out:
# Make                                 object
# Model                                object
# Vehicle Class                        object
# Engine Size(L)                      float64
# Cylinders                             int64
# Transmission                         object
# Fuel Type                            object
# Fuel Consumption City (L/100 km)    float64
# Fuel Consumption Hwy (L/100 km)     float64
# Fuel Consumption Comb (L/100 km)    float64
# Fuel Consumption Comb (mpg)           int64
# CO2 Emissions(g/km)                   int64
# dtype: object

# %%
plt.figure(figsize = (10,6))
sns.heatmap(data.corr(),annot = True)
# Out:
# <AxesSubplot:>

# %%
correlation=data.corr()
correlation
# Out:
#                                   Engine Size(L)  Cylinders  \
# Engine Size(L)                          1.000000   0.927653
# Cylinders                               0.927653   1.000000
# Fuel Consumption City (L/100 km)        0.831379   0.800702
# Fuel Consumption Hwy (L/100 km)         0.761526   0.715252
# Fuel Consumption Comb (L/100 km)        0.817060   0.780534
# Fuel Consumption Comb (mpg)            -0.757854  -0.719321
# CO2 Emissions(g/km)                     0.851145   0.832644
#
#                                   Fuel Consumption City (L/100 km)  \
# Engine Size(L)                                            0.831379
# Cylinders                                                 0.800702
# Fuel Consumption City (L/100 km)                          1.000000
# Fuel Consumption Hwy (L/100 km)                           0.948180
# Fuel Consumption Comb (L/100 km)                          0.993810
# Fuel Consumption Comb (mpg)                              -0.927059
# ...

# %% [markdown]
# #### drop some columns which have less than 60% correlation with our target column CO2emission

# %%
new_columns = correlation[abs(correlation['CO2 Emissions(g/km)']) > 0.5].index.tolist()
new_columns
# Out:
# ['Engine Size(L)',
#  'Cylinders',
#  'Fuel Consumption City (L/100 km)',
#  'Fuel Consumption Hwy (L/100 km)',
#  'Fuel Consumption Comb (L/100 km)',
#  'Fuel Consumption Comb (mpg)',
#  'CO2 Emissions(g/km)']

# %%
sns.heatmap(data[new_columns].corr(),cmap='coolwarm',annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(data, kind="reg")
plt.show()

# %%
Data= data[['Engine Size(L)',
 'Cylinders',
 'Fuel Consumption City (L/100 km)',
 'Fuel Consumption Hwy (L/100 km)',
 'Fuel Consumption Comb (L/100 km)',
 'Fuel Consumption Comb (mpg)',
 'CO2 Emissions(g/km)']]
Data.tail()
# Out:
#       Engine Size(L)  Cylinders  Fuel Consumption City (L/100 km)  \
# 7380             2.0          4                              10.7
# 7381             2.0          4                              11.2
# 7382             2.0          4                              11.7
# 7383             2.0          4                              11.2
# 7384             2.0          4                              12.2
#
#       Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 7380                              7.7                               9.4
# 7381                              8.3                               9.9
# 7382                              8.6                              10.3
# 7383                              8.3                               9.9
# 7384                              8.7                              10.7
#
#       Fuel Consumption Comb (mpg)  CO2 Emissions(g/km)
# 7380                           30                  219
# ...

# %% [markdown]
# ## LINEAR REGRESSION MODEL

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn import metrics

# %%
X = Data.drop('CO2 Emissions(g/km)', axis = 1)
y = Data['CO2 Emissions(g/km)']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print(lr.intercept_)
# Out:
# 224.325386807847

# %%
test_predictions = lr.predict(X_test)
pd.DataFrame(test_predictions)
# Out:
#                0
# 0     257.367879
# 1     321.742868
# 2     324.697485
# 3     306.279956
# 4     296.070268
# ...          ...
# 1842  265.835407
# 1843  301.358082
# 1844  296.060750
# 1845  267.790982
# 1846  189.388374
#
# [1847 rows x 1 columns]

# %%
train_predictions = lr.predict(X_train)
pd.DataFrame(train_predictions)
# Out:
#                0
# 0     252.300168
# 1     352.076041
# 2     190.716521
# 3     220.565123
# 4     324.212036
# ...          ...
# 5533  209.898367
# 5534  232.105403
# 5535  254.563435
# 5536  204.707165
# 5537  290.856907
#
# [5538 rows x 1 columns]

# %%
print("Test Accuracy : ",r2_score(test_predictions,y_test))
print("Training Accuracy : ",r2_score(train_predictions,y_train))
# Out:
# Test Accuracy :  0.8912840057801317
# Training Accuracy :  0.8948615756285304

# %%
print('MAE:', metrics.mean_absolute_error(y_test, test_predictions))
print('MSE:', metrics.mean_squared_error(y_test, test_predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, test_predictions)))
# Out:
# MAE: 11.532910880088489
# MSE: 338.0164613547498
# RMSE: 18.385223995229154

# %% [markdown]
# ## RANDOM FOREST REGRESSOR

# %%
from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 10, random_state = 0)

# %%
regressor.fit(X_train, y_train)
# Out:
# RandomForestRegressor(n_estimators=10, random_state=0)

# %%
prediction = regressor.predict(X_test)
pd.DataFrame(prediction)
# Out:
#                0
# 0     253.000000
# 1     343.662500
# 2     323.950000
# 3     295.816737
# 4     308.200000
# ...          ...
# 1842  260.300000
# 1843  290.800000
# 1844  277.400000
# 1845  280.000000
# 1846  185.200000
#
# [1847 rows x 1 columns]

# %%
predictionss = regressor.predict(X_train)

# %%
print("Test Accuracy : ",r2_score(prediction,y_test))
print("Training Accuracy : ",r2_score(predictionss,y_train))
# Out:
# Test Accuracy :  0.9767000278584519
# Training Accuracy :  0.9962516563801229

# %%
print('MAE:', metrics.mean_absolute_error(y_test, prediction))
print('MSE:', metrics.mean_squared_error(y_test, prediction))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, prediction)))
# Out:
# MAE: 3.2561339013708377
# MSE: 77.32070259390649
# RMSE: 8.79321912577564

# %%
#saving model to disk
pickle.dump(regressor, open('model.pkl','wb'))

# %%
#loading model to compare result
model = pickle.load(open('model.pkl','rb'))
